# %%
import requests 
from bs4 import BeautifulSoup as bs
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
#creating an empty review list
iphone_reviews = []

# %%
for i in range (1,21):
    ip=[]
    url ="https://www.amazon.in/product-reviews/B08L5T44CQ/ref=acr_dp_hist_5?ie=UTF8&filterByStar=five_star&reviewerType=all_reviews#reviews-filter-bar="+str(i)
    response = requests.get(url)
    soup = bs(response.content,"html.parser")
    reviews = soup.findAll("span",attrs = {"class","a-size-base review-text review-text-content"})
    for i in range(len(reviews)):
        ip.append(reviews[i].text)
    iphone_reviews = iphone_reviews+ip

# %%
##Writing reviews in a text file
with open("iphone.txt","w",encoding = 'utf-8') as output:
    output.write(str(iphone_reviews))

# %%
import os
os.getcwd()
# Out:
# '/home/suraj/Data science - ExcelR /Assignments'

# %%
## Joining all the reviews into single paragraph
red_rev_string = " ".join(iphone_reviews)

# %%
##Removing unwanted symbols in case present
red_rev_string = re.sub("[^A-Za-z" "]+"," ",red_rev_string).lower()
red_rev_string =re.sub("[0-9" "]+"," ",red_rev_string)

# %%
##Splitting each word with space -- Tokanization
red_rev_words = red_rev_string.split(" ")

# %%
import nltk
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
red_rev_words = [w for w in red_rev_words if not w in stop_words]

# %%
## Joining all the reviews into single paragraph
red_rev_string =" ".join(red_rev_words)

# %%
# WordCloud can be performed on the string inputs. That is the reason we have combined 
# entire reviews into single paragraph
# Simple word cloud

wordcloud_ip = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(red_rev_string)

# %%
plt.imshow(wordcloud_ip)

# %%
# negative words  Choose path for -ve words stored in system
with open("/home/suraj/Downloads/Assignments/Assignment-11/negative-words.txt","r") as neg:
     negwords = neg.read().split("\n")

# %%
negwords =negwords[37:]

# %%
##Considering only the words which are present in the positive words

red_pos = " ".join([w for w in red_rev_words if w in negwords])

# %%
##Building Positive word cloud
wordcloud_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(red_pos)

plt.imshow(wordcloud_pos)

# %%
##Unique words
red_unique = list(set(" ".join(iphone_reviews).split(" ")))
red_unique
# Out:
# ['',
#  'now.',
#  'light',
#  'side,',
#  'sharp.',
#  'capacity',
#  'worth',
#  '12MP',
#  'phone',
#  'giving',
#  'this',
#  'pro,',
#  'eyes',
#  'one',
#  'cons',
#  'smartphone,as',
#  'out',
#  'hand',
#  'bezel',
#  'pic.This',
#  'great.',
#  'problem.',
#  'battery.',
#  'responsive',
#  'edges.',
#  'In',
#  'excellent',
#  'However,',
#  'usage',
#  'problem',
#  'evening',
#  'Signal,',
#  'tasks',
#  'effect',
#  'height',
#  'hand.',
#  'near',
#  'phone.',
#  'longer',
#  'hands',
#  'becomes',
#  'extra',
#  'you',
#  'etc.This',
#  'available',
#  'yet.',
#  'photographer',
#  'It',
#  'yesterday',
#  'smartphones.',
#  'ramifications.',
#  'sleek',
#  'falling',
#  '\n\n',
#  'iPhone.',
#  'measure',
#  'buy',
#  'iPhone12pro',
#  'far',
#  'phenomenal.',
#  'twice.',
#  'One',
#  'long',
#  'ever',
#  'video',
#  'slippery.',
#  'an',
#  'To',
#  'VerdictOverall,',
#  'imaging',
#  'or',
#  "Haven't",
#  'perfection!',
#  'it.',
#  'get',
#  'shorter',
#  'seen',
#  'also',
#  'can',
#  'amazing.\n\n',
#  'spent',
#  'Awesome.',
#  'phones',
#  'time',
#  'pretty',
#  'especially',
#  'end',
#  'office',
#  'Is',
#  'gives',
#  'is',
#  'Night',
#  'I’m',
#  'taking',
#  'those',
#  'think',
#  'it!!So',
#  'purchased',
#  'other',
#  'square,',
#  'mobile.The',
#  'at',
#  'well.',
#  'As',
#  'bit!!',
#  'heating',
#  'So',
#  'on',
#  'its',
#  'right-angled',
#  'like',
#  'battery!!!.',
#  'picture',
#  'safely',
#  'wow,',
#  'smaller',
#  'border',
#  'view',
#  'appliances,',
#  'changed',
#  'further,',
#  'pro.',
#  'battery,',
#  'easily',
#  'display',
#  'From',
#  'handle.',
#  'X,',
#  'wide',
#  'professional',
#  'just',
#  '1',
#  'minus.',
#  'never',
#  'takes',
#  'better.',
#  'yes,',
#  'UI',
#  'complaints',
#  'It’s',
#  "won't",
#  'moist,',
#  'too',
#  'a',
#  '12.',
#  'battery',
#  'issues',
#  'your',
#  'used',
#  'premium',
#  'good!!!!!!!!The',
#  'mine,',
#  'against',
#  'from',
#  'these',
#  'was',
#  '-',
#  'nothing',
#  'portrait',
#  'time,',
#  'that,',
#  'Dont',
#  'night',
#  'multiple',
#  'Many',
#  'great',
#  'as',
#  'automatically,',
#  "don't",
#  'regular',
#  'better',
#  'thickness',
#  'perfect.The',
#  'stands',
#  'user.',
#  'injuries.',
#  'smoother',
#  'improve',
#  'does',
#  'design',
#  'of',
#  'modern',
#  'health.\n\n',
#  'fanboys',
#  'cameras',
#  'good',
#  'avoid',
#  'filter',
#  'it',
#  'say',
#  'day',
#  'Lidar',
#  'Camera',
#  'blown',
#  'tones.Image',
#  'smooth',
#  'perfect',
#  'Finish',
#  'problem.***',
#  'reports',
#  'correct',
#  'make',
#  '4S,',
#  'note',
#  'use',
#  'laughable.\n\n',
#  'comfortable',
#  'jump',
#  'very',
#  'DSLR',
#  'which',
#  'The',
#  'single',
#  'Android.',
#  'serious',
#  'r',
#  'Especially',
#  'without',
#  'product',
#  'pro',
#  'life.',
#  'tiny',
#  'awesome!',
#  'decent',
#  'best,',
#  'with',
#  'Oh',
#  'remakes.',
#  'really',
#  'lasts',
#  'continuous',
#  'pic',
#  'point',
#  'to',
#  'say!',
#  'good!!\n\n',
#  'closed',
#  'heavy',
#  'environment',
#  '11',
#  'experience',
#  'Please',
#  'working',
#  'details',
#  'case.',
#  'hand-handling',
#  'usual',
#  'so',
#  'tightening',
#  'Battery',
#  'Mode',
#  'penny',
#  'feel',
#  'bit',
#  'ok',
#  'three',
#  'Go',
#  'dslr.\n\n',
#  "I'm",
#  '👍\n\n',
#  'much',
#  'huge',
#  'return.',
#  'lens',
#  'do',
#  'find',
#  'straight',
#  'flaw',
#  'Video',
#  'miles',
#  'most',
#  'save',
#  'technology',
#  'slow.',
#  'after',
#  'case',
#  'received',
#  'rate',
#  'handle,',
#  'about',
#  'though',
#  'aspect',
#  'who',
#  'back',
#  'everything',
#  'away',
#  'Android',
#  'simply',
#  'predecessor',
#  'performance',
#  'made',
#  'mark',
#  'balance',
#  'have',
#  'audio.When',
#  'in',
#  'but',
#  'two',
#  'smartphone',
#  'however,',
#  'There',
#  'respect',
#  'battery!!!,',
#  'now,',
#  'tends',
#  'Prebooked',
#  'Several',
#  'refresh',
#  'loves',
#  'noise',
#  'looking',
#  'Display',
#  'will',
#  'edges',
#  'clear',
#  'Apple',
#  'it.\n\n',
#  'Every',
#  'Review',
#  'Premium',
#  'camera.',
#  'phone.The',
#  'then',
#  'Mode.',
#  'means',
#  'able',
#  'particularly',
#  'turns',
#  'meetings.\n\n',
#  'issue',
#  'matters.The',
#  'gripping',
#  'before',
#  'no',
#  'world',
#  'are',
#  'leaves',
#  'we',
#  'pass',
#  'it,',
#  'month',
#  'that',
#  'things',
#  'any',
#  'Opened',
#  'move',
#  'Quality',
#  'item',
#  'digital',
#  'aspects.It',
#  'upgrade',
#  'ultra',
#  '.ProsThis',
#  'mine',
#  'king',
#  'quality',
#  'for',
#  'major',
#  '7.4mm',
#  'For',
#  'Equivalent/better',
#  'mode',
#  'shown',
#  'since',
#  'grip',
#  'tighten',
#  '12pro',
#  'by',
#  'unbelievably',
#  'got',
#  'skin',
#  'though.',
#  'product\n\n',
#  'may',
#  'stabilization',
#  'imitations.',
#  'thick',
#  'and',
#  'camera',
#  'our',
#  'Wifi',
#  'easy',
#  'give',
#  'I',
#  '.**',
#  'every',
#  'stylish.The',
#  'android',
#  '12',
#  '2020',
#  'times.',
#  'Interestingly,',
#  'uses',
#  'man,electronic',
#  'be',
#  'illness,',
#  'much.',
#  'If',
#  'This',
#  'Everything',
#  'the',
#  'felt',
#  'positive',
#  'palm.',
#  'device.',
#  'iPhone',
#  'game',
#  'there',
#  'prevent',
#  'zoom',
#  'little',
#  'right',
#  'lower',
#  'charging',
#  'stick',
#  'need',
#  'has',
#  'mode,',
#  'looks',
#  'backup',
#  'calls',
#  'higher',
#  'Pro',
#  'handle',
#  'hanging.The',
#  'stunning',
#  'fanboy',
#  'all',
#  'perhaps',
#  '.ConsThere',
#  'phone,',
#  'Just',
#  'expected',
#  'Sensor',
#  'metal',
#  'awesome.\n\n',
#  'device',
#  'network',
#  'telephoto',
#  'iPhone12',
#  'nicely,',
#  'only',
#  'force',
#  "I'll",
#  'writing',
#  'X',
#  'go',
#  'many',
#  'comes',
#  'than',
#  'low-light',
#  'am',
#  'truly',
#  'afford',
#  'world.',
#  'We',
#  'even',
#  'good.',
#  '&',
#  'Those',
#  'good!',
#  'outside',
#  'users',
#  'crowd.',
#  'pictures,',
#  'subsequent',
#  'not',
#  'along',
#  'high',
#  'scar',
#  'been',
#  'sub-consciously',
#  'ground,',
#  'angles.',
#  'view,',
#  'beated',
#  'everything’s',
#  'generation.Final',
#  'market',
#  'now',
#  'previous',
#  'time.So',
#  'still',
#  'best',
#  'Only',
#  'tones',
#  'width',
#  'feels',
#  'quite']

# %% [markdown]
# ### Emotion Mining

# %%
#Sentiment analysis
import pandas as pd
afinn = pd.read_csv('/home/suraj/Downloads/Assignments/Assignment-11/Afinn.csv', sep=',', encoding='latin-1')
afinn.shape
# Out:
# (2477, 2)

# %%
from nltk import tokenize
red_unique = tokenize.sent_tokenize(" ".join(iphone_reviews))
red_unique[5:15]
# Out:
# ["Only issue is it does not have a higher refresh rate but you won't feel that in a tiny bit!!",
#  'Go for it!',
#  '!So far the the battery is just ok I really expected longer life.',
#  'So far so good!!',
#  'Just made an upgrade from iPhone X to iPhone 12 pro, and I’m simply so blown away by the camera of this phone, the quality of the picture it takes is so very near to that of a high end digital camera.',
#  'The portrait mode, the night mode, the regular mode, wow, everything just got so much better.',
#  'This is truly a camera king smartphone available on the market right now.',
#  'If you are a photographer or loves taking pictures, think no further, just jump in straight with eyes closed to get this phone.The only cons I find with this phone is battery tends to be on the shorter side, other than that, everything’s just so very near to perfection!',
#  '👍\n\n \n\n  It’s the best iPhone yet.',
#  'Camera and display is amazing.']

# %%
sent_df = pd.DataFrame(red_unique, columns=['word'])
sent_df
# Out:
#                                                   word
# 0    \n\n  The iPhone 12 Pro has three cameras agai...
# 1    So there is an extra 12MP telephoto lens along...
# 2    Interestingly, the telephoto and the ultra wid...
# 3    One of the best looking phone in the market ri...
# 4    Camera is excellent and the display is quite r...
# ..                                                 ...
# 589  I have Prebooked this iPhone12 pro and receive...
# 590  This iPhone 12pro Is the best in all the thing...
# 591  In Night Mode there is correct balance of ligh...
# 592  The video is so smooth with correct audio.When...
# 593  We purchased the product for our office use an...
#
# [594 rows x 1 columns]

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()

# %%
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English

# %%
#Custom function :score each word in a sentence in lemmatised form, 
#but calculate the score for the whole original sentence.
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        word = nlp(text)
        for word in red_unique:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %%
#Custom function :score each word in a sentence in lemmatised form, 
#but calculate the score for the whole original sentence.
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %%
# test that it works
calculate_sentiment(text = 'good')
# Out:
# 3

# %%
sent_df['sentiment_value'] = sent_df['word'].apply(calculate_sentiment)

# %%
# how many words are in the sentence?
sent_df['word_count'] = sent_df['word'].str.split().apply(len)
sent_df['word_count'].head(10)
# Out:
# 0    14
# 1    22
# 2    17
# 3    19
# 4    11
# 5    20
# 6     3
# 7    13
# 8     4
# 9    42
# Name: word_count, dtype: int64

# %%
sent_df.sort_values(by='sentiment_value').tail(10)
# Out:
#                                                   word  sentiment_value  \
# 353  As usual great & premium phone of 2020 .ProsTh...                6
# 524  This iPhone 12pro Is the best in all the thing...               11
# 458  This iPhone 12pro Is the best in all the thing...               11
# 194  This iPhone 12pro Is the best in all the thing...               11
# 326  This iPhone 12pro Is the best in all the thing...               11
# 128  This iPhone 12pro Is the best in all the thing...               11
# 62   This iPhone 12pro Is the best in all the thing...               11
# 590  This iPhone 12pro Is the best in all the thing...               11
# 392  This iPhone 12pro Is the best in all the thing...               11
# 260  This iPhone 12pro Is the best in all the thing...               11
#
#      word_count
# 353          32
# 524          41
# 458          41
# 194          41
# 326          41
# 128          41
# 62           41
# 590          41
# 392          41
# 260          41

# %%
# Sentiment score of the whole review
sent_df['sentiment_value'].describe()
# Out:
# count    594.000000
# mean       1.333333
# std        2.246977
# min       -3.000000
# 25%        0.000000
# 50%        0.000000
# 75%        3.000000
# max       11.000000
# Name: sentiment_value, dtype: float64

# %%
# Sentiment score of the whole review
sent_df[sent_df['sentiment_value']<=0].head()
# Out:
#                                                 word  sentiment_value  \
# 0  \n\n  The iPhone 12 Pro has three cameras agai...                0
# 1  So there is an extra 12MP telephoto lens along...                0
# 2  Interestingly, the telephoto and the ultra wid...                0
# 5  Only issue is it does not have a higher refres...                0
# 6                                         Go for it!                0
#
#    word_count
# 0          14
# 1          22
# 2          17
# 5          20
# 6           3

# %%
sent_df[sent_df['sentiment_value']>=10].head()
# Out:
#                                                   word  sentiment_value  \
# 62   This iPhone 12pro Is the best in all the thing...               11
# 128  This iPhone 12pro Is the best in all the thing...               11
# 194  This iPhone 12pro Is the best in all the thing...               11
# 260  This iPhone 12pro Is the best in all the thing...               11
# 326  This iPhone 12pro Is the best in all the thing...               11
#
#      word_count
# 62           41
# 128          41
# 194          41
# 260          41
# 326          41

# %%
sent_df['index']=range(0,len(sent_df))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(sent_df['sentiment_value'])
# Out:
# <AxesSubplot:xlabel='sentiment_value', ylabel='Count'>

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(y='sentiment_value',x='index',data=sent_df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='sentiment_value'>

# %%
sent_df.plot.scatter(x='word_count', y='sentiment_value', figsize=(8,8), title='Sentence sentiment value to sentence word count')
# Out:
# <AxesSubplot:title={'center':'Sentence sentiment value to sentence word count'}, xlabel='word_count', ylabel='sentiment_value'>
